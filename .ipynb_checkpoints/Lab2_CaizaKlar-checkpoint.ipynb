# %% [markdown]
# # LABORATORIO 2 CAIZA KLAR

# %% [markdown]
# ## Árboles de decisión

# %%
'''Importamos las respectivas librerias para el 
desarrollo del laboratorio y de igual manera con las librerias para 
el arbol de decision'''
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
'''Cargamos el conjunto de datos contenidos dentro del archivo csv'''
df = pd.read_csv('pacientes2.csv', engine = 'python', index_col=0)

# %%
'''Imprimiremos las primeras 5 filas del archivo, el cual posee informacion
acerca de personas a los que se le fueron tomados los niveles de glucosa,
trigilceridos, presion, arterial entr otros. Ademas muestra si esta persona 
esta enferma o no'''
df.head()
# Out:
#         Enfermedad  HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  EDAD  \
# NOEXPED
# 1               NO         0         0        1         0         0    38
# 2               SI         0         1        1         1         1    49
# 3               SI         1         1        0         1         1    59
# 4               NO         1         1        0         0         0    44
# 5               NO         0         0        1         0         0    42
#
#          GENERO  FUMA  ALCOHOL  POLIURIA
# NOEXPED
# 1             0     0        0         0
# 2             1     0        0         0
# 3             1     0        0         1
# 4             0     0        0         0
# 5             0     0        0         0

# %%
'''Verificamos si las variables fueron cargadas correctamente a traves
de la funcion info'''
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 985 entries, 1 to 909
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Enfermedad  985 non-null    object
#  1   HIPERTEN    985 non-null    int64
#  2   HIPERGLU    985 non-null    int64
#  3   HDLBAJA     985 non-null    int64
#  4   HIPERTRI    985 non-null    int64
#  5   CINTALTA    985 non-null    int64
#  6   EDAD        985 non-null    int64
#  7   GENERO      985 non-null    int64
#  8   FUMA        985 non-null    int64
#  9   ALCOHOL     985 non-null    int64
#  10  POLIURIA    985 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 92.3+ KB

# %%
'''Separamos la variable a predecir de las variables predictoras, se hace
uso de la funcion iloc que permite indicar la ubicacion de cada una de estas'''
X=df.iloc[:,1:11]
Y=df.iloc[:,0]
'''Ya incluye la variable a predecir'''
X.head()
# Out:
#          HIPERTEN  HIPERGLU  HDLBAJA  HIPERTRI  CINTALTA  EDAD  GENERO  FUMA  \
# NOEXPED
# 1               0         0        1         0         0    38       0     0
# 2               0         1        1         1         1    49       1     0
# 3               1         1        0         1         1    59       1     0
# 4               1         1        0         0         0    44       0     0
# 5               0         0        1         0         0    42       0     0
#
#          ALCOHOL  POLIURIA
# NOEXPED
# 1              0         0
# 2              0         0
# 3              0         1
# 4              0         0
# 5              0         0

# %%
'''Usamos la funcion importa de sklearn train_test_split, el cual 
dividira el conjunto de datos de entrenamiento y prueba 
seleccionando registros al azar'''
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.75, random_state=0)

# %%
'''Imprima la informacion de la tabla de entrenamiento'''
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 246 entries, 58 to 28
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HIPERTEN  246 non-null    int64
#  1   HIPERGLU  246 non-null    int64
#  2   HDLBAJA   246 non-null    int64
#  3   HIPERTRI  246 non-null    int64
#  4   CINTALTA  246 non-null    int64
#  5   EDAD      246 non-null    int64
#  6   GENERO    246 non-null    int64
#  7   FUMA      246 non-null    int64
#  8   ALCOHOL   246 non-null    int64
#  9   POLIURIA  246 non-null    int64
# dtypes: int64(10)
# memory usage: 21.1 KB

# %%
'''Mediante la funcion DecisionTreeClassifier generamos la estrucuta del 
arbol de decision y a traves de max_depth se puede agregar la cantidad 
que debe tener el arbol'''
arbol = DecisionTreeClassifier(max_depth=4)

'''A traves dela funcion fit pasaremos como pametros las variables predictoras
como la variable a predecir'''
arbol_enfermedad = arbol.fit(X_train, Y_train)

# %%
'''Creamos una figura con las dimensiones deseadas en ancho y largo a traaaves de 
plt.figure'''
fig = plt.figure(figsize=(25,20))

'''A traves de la funcion tree.plot_tree crearemos el grafico del arbol indicando la 
funcion a graficar'''
tree.plot_tree(arbol_enfermedad, feature_names=list(X.columns.values),class_names=list(Y.values),filled=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="2499.9999627470975">

# %%
'''Guardamos el arbol en la computadora'''
fig.savefig("ArbolDecision.png")

# %%
'''Calculo de la prediccion con los datos obtenidos'''
Y_pred = arbol_enfermedad.predict(X_test)
Y_pred
# Out:
# array(['SI', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
#        'SI', 'NO', 'SI', 'SI', 'SI', 'NO', 'SI', 'SI', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'SI', 'NO', 'SI', 'NO', 'NO', 'SI', 'NO', 'NO',
#        'SI', 'NO', 'SI', 'NO', 'NO', 'NO', 'SI', 'NO', 'SI', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO',
#        'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'NO', 'SI', 'SI', 'NO', 'SI',
#        'NO', 'NO', 'NO', 'NO', 'SI', 'SI', 'NO', 'SI', 'NO', 'NO', 'SI',
#        'NO', 'NO', 'SI', 'NO', 'NO', 'SI', 'SI', 'NO', 'NO', 'NO', 'NO',
#        'NO', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO', 'NO', 'SI', 'NO', 'NO',
# ...

# %%
'''Calculamos la precision del modelo. Creamos la matriz de confusion
a traves de la funcion confusion_matrix pasando el Ytest y Y_pred y pedimos 
que se muestren'''
Matriz_Confusion = confusion_matrix(Y_test,Y_pred)
Matriz_Confusion
# Out:
# array([[507,  15],
#        [ 50, 167]], dtype=int64)

# %%
'''Para calcular la precision global del modelo se suman los valores correctos
predichos divididos para la suma de ltodos los valores incluidos en la matriz'''
Precision_Global = np.sum(Matriz_Confusion.diagonal())/np.sum(Matriz_Confusion)
Precision_Global
# Out:
# 0.912043301759134

# %%
'''Obtenemos la precision por cada una de las clases , ya que el modelo global
no confirma si el modelo es bueno prediciendo, de este modo se obtuvo la precision 
de no eermos '''
Precision_No = ((Matriz_Confusion[0,0]))/sum(Matriz_Confusion[0,])
Precision_No
# Out:
# 0.9712643678160919

# %%
'''Obtenemos la precision por cada una de las clases , ya que el modelo global
no confirma si el modelo es bueno prediciendo, de este modo se obtuvo la precision 
de si eermos '''
Precision_Si = ((Matriz_Confusion[1,1]))/sum(Matriz_Confusion[1,])
Precision_Si
# Out:
# 0.7695852534562212

# %%
'''De manera mas resumida se obtendran los datos
a traves de ka funcion classification report'''
print(metrics.classification_report(Y_test, Y_pred, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#           NO      0.910     0.971     0.940       522
#           SI      0.918     0.770     0.837       217
#
#     accuracy                          0.912       739
#    macro avg      0.914     0.870     0.888       739
# weighted avg      0.912     0.912     0.910       739

# %%
'''Procederemos a agregar nombres en la matriz'''
Matriz_Confusion_df = pandas.DataFrame(Matriz_Confusion,
                     index = ['Esta enfermo', 'No Esta enfermo'], 
                     columns = ['No Esta enfermo', 'Esta enfermo'])

# %%
'''Imprimira la matriz de confucion creada a traves de 
seaborn y hetmap'''
plt.figure(figsize=(5,4))
sns.heatmap(Matriz_Confusion_df, annot=True, fmt='g')
plt.title('Matriz de confusion')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.9999925494195">
